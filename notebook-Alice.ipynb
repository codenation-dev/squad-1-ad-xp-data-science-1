# %%
import pandas as pd

# %%
port_1 = pd.read_csv("estaticos_portfolio1.csv")
port_2 = pd.read_csv("estaticos_portfolio2.csv")
port_3 = pd.read_csv("estaticos_portfolio3.csv")
mercado = pd.read_csv("estaticos_market.csv")

# %%
mercado.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'fl_matriz', 'de_natureza_juridica', 'sg_uf',
#        'natureza_juridica_macro', 'de_ramo', 'setor',
#        'idade_empresa_anos', 'idade_emp_cat', 'fl_me', 'fl_sa', 'fl_epp',
#        'fl_mei', 'fl_ltda', 'dt_situacao', 'fl_st_especial', 'fl_email',
#        'fl_telefone', 'fl_rm', 'nm_divisao', 'nm_segmento', 'fl_spa',
#        'fl_antt', 'fl_veiculo', 'vl_total_tancagem',
#        'vl_total_veiculos_antt', 'vl_total_veiculos_leves',
#        'vl_total_veiculos_pesados', 'fl_optante_simples', 'qt_art',
#        'vl_total_veiculos_pesados_grupo', 'vl_total_veiculos_leves_grupo',
#        'vl_total_tancagem_grupo', 'vl_total_veiculos_antt_grupo',
#        'vl_potenc_cons_oleo_gas', 'fl_optante_simei', 'sg_uf_matriz',
#        'de_saude_tributaria', 'de_saude_rescencia', 'nu_meses_rescencia',
#        'de_nivel_atividade', 'de_indicador_telefone',
#        'fl_simples_irregular', 'vl_frota',
# ...

# %%
mercado.describe()
# Out:
#          Unnamed: 0  idade_empresa_anos  vl_total_tancagem  \
# count  462298.00000       462298.000000         280.000000
# mean   231148.50000            9.948677          32.014286
# std    133454.08171            9.615664          81.280168
# min         0.00000            0.016438           1.000000
# 25%    115574.25000            2.756164          15.000000
# 50%    231148.50000            6.704110          15.000000
# 75%    346722.75000           14.465753          30.000000
# max    462297.00000          106.432877        1215.000000
#
#        vl_total_veiculos_antt  vl_total_veiculos_leves  \
# count              176.000000             30684.000000
# mean                 3.818182                 2.244329
# std                  6.797555                 9.572536
# min                  0.000000                 0.000000
# 25%                  1.000000                 0.000000
# 50%                  2.000000                 1.000000
# ...

# %%
port_1.head()
# Out:
#    Unnamed: 0                                                 id  fl_matriz  \
# 0           0  dabe79bec87c88ae04e869bf6bd321ee5e1893cecf6625...       True
# 1           1  32e5f4e10932153a7ba869cb0386e7e02d49d2461046b8...      False
# 2           2  a95d6f30bba445bd3d6b0c5b36f865b38ec01d17336090...       True
# 3           3  6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e...       True
# 4           4  f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc25...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 1          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    RN                  OUTROS
# 4  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#               de_ramo     setor  idade_empresa_anos idade_emp_cat  ...  \
# ...

# %%
port_2.head()
# Out:
#    Unnamed: 0                                                 id
# 0           0  09e95c1a84049001d086470a8f320a19b076f955a89122...
# 1           1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...
# 2           2  16843c9ffb920170477118933798510d8d5f00f5c56c12...
# 3           3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...
# 4           4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...

# %%
port_3.head()
# Out:
#    Unnamed: 0                                                 id
# 0           0  bb61c09449a1c1f8b78955d8b7a7f73599e78358993fe2...
# 1           1  16843c9ffb920170477118933798510d8d5f00f5c56c12...
# 2           2  1b8d092daff12bed8b3c2ab93bf5df2921865a68aca185...
# 3           3  3aafa3a1f12f483740a52956af100223333d0e3c79bf2c...
# 4           4  c60431fbca90067f105570e1e8a684bcd7048205bbf6c4...

# %%
mercado.head()
# Out:
#    Unnamed: 0                                                 id  fl_matriz  \
# 0           0  a6984c3ae395090e3bee8ad63c3758b110de096d5d8195...       True
# 1           1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...       True
# 2           2  4a7e5069a397f12fdd7fd57111d6dc5d3ba558958efc02...       True
# 3           3  3348900fe63216a439d2e5238c79ddd46ede454df7b9d8...       True
# 4           4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
# 1          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 4          EMPRESARIO INDIVIDUAL    RN                  OUTROS
#
#                                           de_ramo             setor  \
# ...

# %%
port1 = port_1.drop(['Unnamed: 0'] , axis='columns')
port2 = port_2.drop(['Unnamed: 0'] , axis='columns')
port3 = port_3.drop(['Unnamed: 0'] , axis='columns')
merc = mercado.drop(['Unnamed: 0'] , axis='columns')

# %%
p1 = port1.copy()

# %%
p2 = pd.merge(port2, merc, on='id', how='inner')
p2.head()
# Out:
#                                                   id  fl_matriz  \
# 0  09e95c1a84049001d086470a8f320a19b076f955a89122...       True
# 1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...       True
# 2  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...       True
# 4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...       True
#
#                         de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  AUTARQUIA ESTADUAL OU DO DISTRITO FEDERAL    AC   ADMINISTRACAO PUBLICA
# 1                                  MUNICIPIO    RN                  OUTROS
# 2                 SOCIEDADE SIMPLES LIMITADA    PI  ENTIDADES EMPRESARIAIS
# 3                                  MUNICIPIO    AM                  OUTROS
# 4              SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#                                              de_ramo         setor  \
# ...

# %%
p3 = pd.merge(port3, merc, on='id', how='inner')
p3.head()
# Out:
#                                                   id  fl_matriz  \
# 0  bb61c09449a1c1f8b78955d8b7a7f73599e78358993fe2...       True
# 1  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 2  1b8d092daff12bed8b3c2ab93bf5df2921865a68aca185...       True
# 3  3aafa3a1f12f483740a52956af100223333d0e3c79bf2c...       True
# 4  c60431fbca90067f105570e1e8a684bcd7048205bbf6c4...       True
#
#                                 de_natureza_juridica sg_uf  \
# 0                                          MUNICIPIO    MA
# 1                         SOCIEDADE SIMPLES LIMITADA    PI
# 2  ORGAO PUBLICO DO PODER EXECUTIVO ESTADUAL OU D...    AM
# 3                                          MUNICIPIO    PI
# 4                                          MUNICIPIO    RN
#
#   natureza_juridica_macro                                            de_ramo  \
# 0                  OUTROS  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL
# ...

# %%
p1.describe()
# Out:
#        idade_empresa_anos  vl_total_tancagem  vl_total_veiculos_antt  \
# count          555.000000                0.0                     0.0
# mean            10.139247                NaN                     NaN
# std              9.641625                NaN                     NaN
# min              0.052055                NaN                     NaN
# 25%              2.924658                NaN                     NaN
# 50%              6.709589                NaN                     NaN
# 75%             15.494521                NaN                     NaN
# max             47.517808                NaN                     NaN
#
#        vl_total_veiculos_leves  vl_total_veiculos_pesados    qt_art  \
# count                38.000000                  38.000000  4.000000
# mean                  1.473684                   0.526316  3.250000
# std                   1.309773                   1.330248  3.201562
# min                   0.000000                   0.000000  1.000000
# ...

# %%
p2.describe()
# Out:
#        idade_empresa_anos  vl_total_tancagem  vl_total_veiculos_antt  \
# count          566.000000          27.000000                 5.00000
# mean            26.987691          39.296296                15.80000
# std             11.638360          67.564109                16.22344
# min             10.038356          10.000000                 2.00000
# 25%             17.832192          15.000000                 6.00000
# 50%             23.402740          15.000000                 6.00000
# 75%             38.628082          30.000000                25.00000
# max             55.126027         360.000000                40.00000
#
#        vl_total_veiculos_leves  vl_total_veiculos_pesados      qt_art  \
# count               490.000000                 490.000000  262.000000
# mean                 11.644898                   9.848980   11.160305
# std                  27.506765                  24.114791   31.223043
# ...

# %%
p3.describe()
# Out:
#        idade_empresa_anos  vl_total_tancagem  vl_total_veiculos_antt  \
# count          265.000000           10.00000                     0.0
# mean            27.762502           22.00000                     NaN
# std             14.119603           11.83216                     NaN
# min              0.761644           15.00000                     NaN
# 25%             17.638356           15.00000                     NaN
# 50%             24.073973           15.00000                     NaN
# 75%             43.800000           26.25000                     NaN
# max             51.808219           45.00000                     NaN
#
#        vl_total_veiculos_leves  vl_total_veiculos_pesados      qt_art  \
# count               221.000000                 221.000000  130.000000
# mean                 12.285068                   9.040724   21.515385
# std                  35.029406                  25.104747   87.800181
# ...

# %%
p1.shape
# Out:
# (555, 181)

# %%
p2.shape
# Out:
# (566, 181)

# %%
p3.shape
# Out:
# (265, 181)
